# %% [markdown]
# To use BigQuery, we'll import the Python package below:

# %%
# !pip install google.cloud.bigquery
# !pip install os
# !pip install pandas
# !pip install pandas-gbq
# !pip install matplotlib
# Out:
# Collecting google.cloud.bigquery
#   Using cached google_cloud_bigquery-3.4.2-py2.py3-none-any.whl (215 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (4.21.12)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (1.22.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (1.51.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (2.28.2)
# Requirement already satisfied: packaging>=20.0.0 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (21.3)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (2.11.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (2.4.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (2.8.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in ./.venv/lib/python3.8/site-packages (from google.cloud.bigquery) (2.3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google.cloud.bigquery) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google.cloud.bigquery) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google.cloud.bigquery) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google.cloud.bigquery) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./.venv/lib/python3.8/site-packages (from packaging>=20.0.0->google.cloud.bigquery) (3.0.9)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in ./.venv/lib/python3.8/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (2.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in ./.venv/lib/python3.8/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (1.58.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2; extra == "grpc" in ./.venv/lib/python3.8/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (1.51.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.venv/lib/python3.8/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google.cloud.bigquery) (1.5.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil<3.0dev,>=2.7.2->google.cloud.bigquery) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in ./.venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./.venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google.cloud.bigquery) (0.4.8)
# Installing collected packages: google.cloud.bigquery
# Successfully installed google.cloud.bigquery
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Requirement already satisfied: pandas in ./.venv/lib/python3.8/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in ./.venv/lib/python3.8/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pandas-gbq in ./.venv/lib/python3.8/site-packages (0.19.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (1.5.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (0.8.0)
# Requirement already satisfied: google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (3.4.2)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (44.0.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (1.0.5)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0.0dev,>=2.16.2 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (2.18.0)
# Requirement already satisfied: numpy>=1.16.6 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (1.24.1)
# Requirement already satisfied: pyarrow>=3.0.0 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (10.0.1)
# Requirement already satisfied: google-auth>=2.13.0 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (2.16.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.10.2 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (2.11.0)
# Requirement already satisfied: pandas>=1.1.4 in ./.venv/lib/python3.8/site-packages (from pandas-gbq) (1.5.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.8/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (1.3.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (2.4.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (1.22.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (1.51.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (4.21.12)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (2.28.2)
# Requirement already satisfied: packaging>=20.0.0 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (21.3)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in ./.venv/lib/python3.8/site-packages (from google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (2.8.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.8/site-packages (from google-auth>=2.13.0->pandas-gbq) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.8/site-packages (from google-auth>=2.13.0->pandas-gbq) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in ./.venv/lib/python3.8/site-packages (from google-auth>=2.13.0->pandas-gbq) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in ./.venv/lib/python3.8/site-packages (from google-auth>=2.13.0->pandas-gbq) (4.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in ./.venv/lib/python3.8/site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (1.58.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas>=1.1.4->pandas-gbq) (2022.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.2.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.venv/lib/python3.8/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (1.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./.venv/lib/python3.8/site-packages (from packaging>=20.0.0->google-cloud-bigquery!=2.4.*,<4.0.0dev,>=3.3.5->pandas-gbq) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./.venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.13.0->pandas-gbq) (0.4.8)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.8/site-packages (3.6.3)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in ./.venv/lib/python3.8/site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: pyparsing>=2.2.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import os
import pandas_gbq
from google.cloud import bigquery
from google.cloud.bigquery.client import Client

# %% [markdown]
# The first step in the workflow is to create a Client object. As you'll soon see, this Client object will play a central role in retrieving information from BigQuery datasets.

# %%
credentials_path = '/home/elias/BigqueryClient.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_path

client = bigquery.Client()

# %% [markdown]
# #### Below we can select some example datasets like:
# - chicago_taxi_trips
# - openaq
# - world_bank_intl_education
# - crypto_bitcoin
# - github_repos

# %%
# Construct a reference to the dataset (Can change openaq to desired dataset )
dataset_ref = client.dataset("chicago_taxi_trips", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there are four!)
for table in tables:  
    print(table.table_id)
# Out:
# taxi_trips

# %% [markdown]
# Similar to how we fetched a dataset, we can fetch a table. In the code cell below, we fetch the full table in the hacker_news dataset.

# %%
# Construct a reference to the "full" table
table_ref = dataset_ref.table("taxi_trips")

# API request - fetch the table
table = client.get_table(table_ref)

# %% [markdown]
# <img src=https://i.imgur.com/biYqbUB.png>

# %%
# Print information on all the columns in the "full" table
table.schema
# Out:
# [SchemaField('unique_key', 'STRING', 'REQUIRED', None, 'Unique identifier for the trip.', (), None),
#  SchemaField('taxi_id', 'STRING', 'REQUIRED', None, 'A unique identifier for the taxi.', (), None),
#  SchemaField('trip_start_timestamp', 'TIMESTAMP', 'NULLABLE', None, 'When the trip started, rounded to the nearest 15 minutes.', (), None),
#  SchemaField('trip_end_timestamp', 'TIMESTAMP', 'NULLABLE', None, 'When the trip ended, rounded to the nearest 15 minutes.', (), None),
#  SchemaField('trip_seconds', 'INTEGER', 'NULLABLE', None, 'Time of the trip in seconds.', (), None),
#  SchemaField('trip_miles', 'FLOAT', 'NULLABLE', None, 'Distance of the trip in miles.', (), None),
#  SchemaField('pickup_census_tract', 'INTEGER', 'NULLABLE', None, 'The Census Tract where the trip began. For privacy, this Census Tract is not shown for some trips.', (), None),
#  SchemaField('dropoff_census_tract', 'INTEGER', 'NULLABLE', None, 'The Census Tract where the trip ended. For privacy, this Census Tract is not shown for some trips.', (), None),
#  SchemaField('pickup_community_area', 'INTEGER', 'NULLABLE', None, 'The Community Area where the trip began.', (), None),
#  SchemaField('dropoff_community_area', 'INTEGER', 'NULLABLE', None, 'The Community Area where the trip ended.', (), None),
#  SchemaField('fare', 'FLOAT', 'NULLABLE', None, 'The fare for the trip.', (), None),
#  SchemaField('tips', 'FLOAT', 'NULLABLE', None, 'The tip for the trip. Cash tips generally will not be recorded.', (), None),
#  SchemaField('tolls', 'FLOAT', 'NULLABLE', None, 'The tolls for the trip.', (), None),
#  SchemaField('extras', 'FLOAT', 'NULLABLE', None, 'Extra charges for the trip.', (), None),
#  SchemaField('trip_total', 'FLOAT', 'NULLABLE', None, 'Total cost of the trip, the total of the fare, tips, tolls, and extras.', (), None),
#  SchemaField('payment_type', 'STRING', 'NULLABLE', None, 'Type of payment for the trip.', (), None),
#  SchemaField('company', 'STRING', 'NULLABLE', None, 'The taxi company.', (), None),
#  SchemaField('pickup_latitude', 'FLOAT', 'NULLABLE', None, 'The latitude of the center of the pickup census tract or the community area if the census tract has been hidden for privacy.', (), None),
#  SchemaField('pickup_longitude', 'FLOAT', 'NULLABLE', None, 'The longitude of the center of the pickup census tract or the community area if the census tract has been hidden for privacy.', (), None),
#  SchemaField('pickup_location', 'STRING', 'NULLABLE', None, 'The location of the center of the pickup census tract or the community area if the census tract has been hidden for privacy.', (), None),
#  SchemaField('dropoff_latitude', 'FLOAT', 'NULLABLE', None, 'The latitude of the center of the dropoff census tract or the community area if the census tract has been hidden for privacy.', (), None),
#  SchemaField('dropoff_longitude', 'FLOAT', 'NULLABLE', None, 'The longitude of the center of the dropoff census tract or the community area if the census tract has been hidden for privacy.', (), None),
#  SchemaField('dropoff_location', 'STRING', 'NULLABLE', None, 'The location of the center of the dropoff census tract or the community area if the census tract has been hidden for privacy.', (), None)]

# %% [markdown]
# ##### We can use the list_rows() method to check just the first five lines of of the full table to make sure this is right.
#
# ##### This returns a BigQuery RowIterator object that can quickly be converted to a pandas DataFrame with the to_dataframe() method.

# %%
# Preview the first five lines of the table
df = client.list_rows(table, max_results=5).to_dataframe()
df.head()
# Out:
#                                  unique_key  \
# 0  c5679468c130f5a58c1c44c8df9f579d513ef940
# 1  ed6013f98c80cad1b1d21f4c5692b28478e8f68d
# 2  0677e4eaabc0a7000cf18999ea5c9af722ab1fea
# 3  a6c433b8961bd9d13a2273440d64df330196aa62
# 4  226ba06675fb6c6527a0f0931b420bb6ba649a9e
#
#                                              taxi_id  \
# 0  bfb5c2ad40103c9891e7ee4713e93ccd75e741099b7498...
# 1  a8078f80a679e11f94f21e3bc8e205025db5e17d1f204c...
# 2  be2af1b95b937dfe54bf9a4f4331745a673529a7edfab2...
# 3  4fdfda1ef9a53850fc350d2834bfd9086e4a622f5e06cd...
# 4  45660b34deeab21b9a6db21b9b77b19eef90236c65683e...
#
#        trip_start_timestamp        trip_end_timestamp  trip_seconds  \
# 0 2014-05-02 18:00:00+00:00 2014-05-02 18:15:00+00:00           540
# 1 2019-04-18 13:45:00+00:00 2019-04-18 14:00:00+00:00           180
# 2 2019-04-19 02:30:00+00:00 2019-04-19 03:00:00+00:00          1860
# 3 2014-06-11 23:30:00+00:00 2014-06-12 00:00:00+00:00          1500
# 4 2019-04-18 12:30:00+00:00 2019-04-18 12:30:00+00:00           360
#
#    trip_miles  pickup_census_tract  dropoff_census_tract  \
# 0         1.0                 <NA>                  <NA>
# 1         0.4                 <NA>                  <NA>
# 2         0.8                 <NA>                  <NA>
# 3         9.0                 <NA>                  <NA>
# 4         0.7                 <NA>                  <NA>
#
#    pickup_community_area  dropoff_community_area  ...  extras  trip_total  \
# 0                   <NA>                    <NA>  ...     0.0        6.45
# 1                   <NA>                    <NA>  ...     1.0        5.50
# 2                   <NA>                      76  ...     0.0       39.25
# 3                   <NA>                    <NA>  ...     0.0       24.90
# 4                   <NA>                    <NA>  ...     0.0        6.25
#
#    payment_type                        company  pickup_latitude  \
# 0          Cash                           None              NaN
# 1          Cash  Taxicab Insurance Agency, LLC              NaN
# 2          Cash      Taxi Affiliation Services              NaN
# 3   Credit Card                           None              NaN
# 4   Credit Card   Chicago Medallion Management              NaN
#
#   pickup_longitude pickup_location  dropoff_latitude  dropoff_longitude  \
# 0              NaN            None               NaN                NaN
# 1              NaN            None               NaN                NaN
# 2              NaN            None         41.980264         -87.913625
# 3              NaN            None               NaN                NaN
# 4              NaN            None               NaN                NaN
#
#                       dropoff_location
# 0                                 None
# 1                                 None
# 2  POINT (-87.913624596 41.9802643146)
# 3                                 None
# 4                                 None
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
# /home/elias/SQL/.venv/lib/python3.8/site-packages/pandas/core/array_algos/quantile.py:207: RuntimeWarning: invalid value encountered in cast
#   and (result == result.astype(values.dtype, copy=False)).all()
# /home/elias/SQL/.venv/lib/python3.8/site-packages/pandas/core/array_algos/quantile.py:207: RuntimeWarning: invalid value encountered in cast
#   and (result == result.astype(values.dtype, copy=False)).all()
# /home/elias/SQL/.venv/lib/python3.8/site-packages/pandas/core/array_algos/quantile.py:207: RuntimeWarning: invalid value encountered in cast
#   and (result == result.astype(values.dtype, copy=False)).all()
#        trip_seconds  trip_miles  pickup_census_tract  dropoff_census_tract  \
# count           5.0     5.00000                  0.0                   0.0
# mean          888.0     2.38000                 <NA>                  <NA>
# std      745.063756     3.70702                 <NA>                  <NA>
# min           180.0     0.40000                 <NA>                  <NA>
# 25%           360.0     0.70000                 <NA>                  <NA>
# 50%           540.0     0.80000                 <NA>                  <NA>
# 75%          1500.0     1.00000                 <NA>                  <NA>
# max          1860.0     9.00000                 <NA>                  <NA>
#
#        pickup_community_area  dropoff_community_area       fare      tips  \
# count                    0.0                     1.0   5.000000  5.000000
# mean                    <NA>                    76.0  15.520000  0.750000
# std                     <NA>                    <NA>  14.998733  1.414214
# min                     <NA>                    76.0   4.500000  0.000000
# 25%                     <NA>                    76.0   5.750000  0.000000
# 50%                     <NA>                    76.0   6.450000  0.000000
# 75%                     <NA>                    76.0  21.650000  0.500000
# max                     <NA>                    76.0  39.250000  3.250000
#
#        tolls    extras  trip_total  pickup_latitude  pickup_longitude  \
# count    5.0  5.000000    5.000000              0.0               0.0
# mean     0.0  0.200000   16.470000              NaN               NaN
# std      0.0  0.447214   15.125996              NaN               NaN
# min      0.0  0.000000    5.500000              NaN               NaN
# 25%      0.0  0.000000    6.250000              NaN               NaN
# 50%      0.0  0.000000    6.450000              NaN               NaN
# 75%      0.0  0.000000   24.900000              NaN               NaN
# max      0.0  1.000000   39.250000              NaN               NaN
#
#        dropoff_latitude  dropoff_longitude
# count          1.000000           1.000000
# mean          41.980264         -87.913625
# std                 NaN                NaN
# min           41.980264         -87.913625
# 25%           41.980264         -87.913625
# 50%           41.980264         -87.913625
# 75%           41.980264         -87.913625
# max           41.980264         -87.913625

# %% [markdown]
# ## Select, From & Where
# Everything looks good! So, let's put together a query.
#
# A query that counts the number of trips in each year

# %%
query = """
                       SELECT EXTRACT(YEAR FROM trip_start_timestamp) AS year, 
                              COUNT(1) AS num_trips
                       FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
                       GROUP BY year
                       ORDER BY year
                       """

# %% [markdown]
# We begin by setting up the query with the query() method. We run the method with the default parameters, but this method also allows us to specify more complicated settings that you can read about in the documentation. We'll revisit this later.

# %%
query_job = client.query(query)
result = query_job.to_dataframe()
result.head()
# Out:
#    year  num_trips
# 0  2013   27217300
# 1  2014   37395079
# 2  2015   32385527
# 3  2016   31756403
# 4  2017   24979611

# %%
us_cities.city.value_counts().head(20)

# %% [markdown]
# ### Dive slightly deeper
# ##### To take a closer look at rides from 2017:
# 1. We use a **WHERE** clause to limit the query to data from 2017.
# 2. Modify the query to extract the month rather than the year.

# %%
query = """
                        SELECT EXTRACT(MONTH FROM trip_start_timestamp) AS month, 
                               COUNT(1) AS num_trips
                        FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
                        WHERE EXTRACT(YEAR FROM trip_start_timestamp) = 2017
                        GROUP BY month
                        ORDER BY month
                        """

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
query_job = client.query(query, job_config=safe_config)

results = query_job.to_dataframe()
results.head(12)
# Out:
#     month  num_trips
# 0       1    1971708
# 1       2    1909479
# 2       3    2361634
# 3       4    2194344
# 4       5    2322631
# 5       6    2323672
# 6       7    2053471
# 7       8    2078623
# 8       9    1949427
# 9      10    2140326
# 10     11    1906884
# 11     12    1767412

# %% [markdown]
# ## Count, Group by & Having, Order by & Extract
#
# ##### COUNT(), returns a count of things. If you pass it the name of a column, it will return the number of entries in that column.
#
# ##### GROUP BY takes the name of one or more columns, and treats all rows with the same value in that column as a single group when you apply aggregate functions like COUNT().
#
# ##### HAVING is used in combination with GROUP BY to ignore groups that don't meet certain criteria.
#
# ##### ORDER BY is usually the last clause in your query, and it sorts the results returned by the rest of your query.
#
# ##### Often you'll want to look at part of a date, like the year or the day. You can do this with EXTRACT.
#
# In the Next Query, for each hour of the day in the dataset, the corresponding number of trips and average speed.
#
# Three columns:
#
# - hour_of_day - sort by this column, which holds the result of extracting the hour from trip_start_timestamp.
# - num_trips - the count of the total number of trips in each hour of the day (e.g. how many trips were started between 6AM and 7AM, independent of which day it occurred on).
# - avg_mph - the average speed, measured in miles per hour, for trips that started in that hour of the day. Average speed in miles per hour is calculated as 3600 * SUM(trip_miles) / SUM(trip_seconds). (The value 3600 is used to convert from seconds to hours.)
#
# Query to data meeting the following criteria:
#
# - a trip_start_timestamp between 2017-01-01 and 2017-07-01
# - trip_seconds > 0 and trip_miles > 0

# %%
query = """
               WITH RelevantRides AS
               (
                   SELECT EXTRACT(HOUR FROM trip_start_timestamp) AS hour_of_day, 
                          trip_miles, 
                          trip_seconds
                   FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
                   WHERE trip_start_timestamp > '2017-01-01' AND 
                         trip_start_timestamp < '2017-07-01' AND 
                         trip_seconds > 0 AND 
                         trip_miles > 0
               )
               SELECT hour_of_day, 
                      COUNT(1) AS num_trips, 
                      3600 * SUM(trip_miles) / SUM(trip_seconds) AS avg_mph
               FROM RelevantRides
               GROUP BY hour_of_day
               ORDER BY num_trips DESC
               """

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
query_job = client.query(query, job_config=safe_config)

results = query_job.to_dataframe()
results.head(24)
# Out:
#     hour_of_day  num_trips    avg_mph
# 0            18     768159  13.648912
# 1            17     756535  12.464977
# 2            16     701345  14.286536
# 3            19     700962  16.646259
# 4            15     640348  15.691071
# 5            13     630109  17.673604
# 6            14     622402  16.976330
# 7            12     622249  17.841610
# 8            20     598536  19.540297
# 9            11     594522  18.931559
# 10            9     565455  16.547683
# 11           21     552658  20.436899
# 12            8     541745  15.081015
# 13           10     525030  18.543678
# 14           22     501059  19.533171
# 15           23     399573  19.878003
# 16            7     358403  17.736209
# 17            0     319326  20.231735
# 18            1     266525  18.937962
# 19            2     210147  18.777070
# 20            6     182736  24.588560
# 21            3     159666  20.158374
# 22            4     122183  26.736014
# 23            5     119311  30.769411

# %%
results.plot(x='hour_of_day', y='num_trips', kind='scatter')
# Out:
# <AxesSubplot: xlabel='hour_of_day', ylabel='num_trips'>
